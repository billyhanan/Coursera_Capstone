# %% [markdown]
# # Capstone Project: Data Collection
#
# 29/11/2020
#
# We collect restaurant data via the Foursquare API.

# %%
import pandas as pd
import numpy as np
import requests 
import json # library to handle JSON files
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
#!pip install folium
import folium # map rendering library

# %%
# Coordinates of Reykjavik
latitude = 64.1466
longitude = -21.9426

# create map of Toronto using latitude and longitude values
map_reykjavik = folium.Map(location=[latitude, longitude], zoom_start=10)
    
map_reykjavik
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# @hidden_cell
CLIENT_ID = '34CRGBIL11CRLO5BNFSRKHWNRQT1GWTB4QKGYG5GLQYM3JKQ' # your Foursquare ID
CLIENT_SECRET = 'HRPY3HMJC1FSPYTC2VRVUANCY1JY20NBRA5400RQYOEOFCNB' # your Foursquare Secret
#VERSION = '20180605' # Foursquare API version
VERSION = '20201123' # Foursquare API version
RADIUS=500
LIMIT = 50 # A default Foursquare API limit value

# %%
# List of categories
afghan = '503288ae91d4c4b30a586d67'
african = '4bf58dd8d48988d1c8941735'
american = '4bf58dd8d48988d14e941735'
asian = '4bf58dd8d48988d142941735'
australian = '4bf58dd8d48988d169941735'
austrian = '52e81612bcbc57f1066b7a01'
bangladesh = '5e179ee74ae8e90006e9a746'
belgium = '52e81612bcbc57f1066b7a02'
cajun = '4bf58dd8d48988d17a941735'
caribbean = '4bf58dd8d48988d144941735'
caucasian = '5293a7d53cf9994f4e043a45'
czech = '52f2ae52bcbc57f1066b8b81'
dutch = '5744ccdfe4b0c0459246b4d0'
eastEurope = '4bf58dd8d48988d109941735'
english = '52e81612bcbc57f1066b7a05'
french = '4bf58dd8d48988d10c941735'
german = '4bf58dd8d48988d10d941735'
greek = '4bf58dd8d48988d10e941735'
hungary = '52e81612bcbc57f1066b79fa'
indian = '4bf58dd8d48988d10f941735'
italian = '4bf58dd8d48988d110941735'
jewish = '52e81612bcbc57f1066b79fd'
latin = '4bf58dd8d48988d1be941735'
meditarranean = '4bf58dd8d48988d1c0941735'
mexican = '4bf58dd8d48988d1c1941735'
middleEast = '4bf58dd8d48988d115941735'
modernEuropean = '52e81612bcbc57f1066b79f9'
pakistan = '52e81612bcbc57f1066b79f8'
polish = '52e81612bcbc57f1066b7a04'
portugal = '4def73e84765ae376e57713a'
russia = '5293a7563cf9994f4e043a44'
scandinavia = '4bf58dd8d48988d1c6941735'
scotland = '5744ccdde4b0c0459246b4a3'
slovak = '56aa371be4b08b9a8d57355a'
spain = '4bf58dd8d48988d150941735'
srilanka = '5413605de4b0ae91d18581a9'
swiss = '4bf58dd8d48988d158941735'
turkey = '4f04af1f2fb6e1c99f3db0bb'
ukraine = '52e928d0bcbc57f1066b7e96'

category_list = [afghan,african,american,asian,australian,austrian,bangladesh,belgium,cajun,caribbean,caucasian,czech,dutch,eastEurope,english,
                 french,german,greek,hungary,indian,italian,jewish,latin,meditarranean,mexican,middleEast,modernEuropean,pakistan,polish,
                 portugal,russia,scandinavia,scotland,slovak,spain,srilanka,swiss,turkey,ukraine] 

CATEGORIES = ','.join(category_list)

# %%
def getVenues(latitude, longitude, RADIUS=500):
    
    url = 'https://api.foursquare.com/v2/venues/search?&categoryId={}&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&intent=browse'.format(
            CATEGORIES,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            latitude, 
            longitude, 
            RADIUS,
            LIMIT)
    
    response = requests.get(url)
    results = response.json()
    
    if response.status_code == 200:
        venues = results['response']['venues']
    else:
        venues = []
        print("HTTP-{}".format(response.status_code))
        
    venue_list = []
    
    number_of_venues = len(venues)
    
    for i in range(number_of_venues):
        
        try:
            venue_id = venues[i]['id']
            venue_name = venues[i]['name']
            lat = venues[i]['location']['lat']
            lng = venues[i]['location']['lng']
            category = venues[i]['categories'][0]['name']
            
            record = (latitude, longitude, number_of_venues, i, venue_id, venue_name, lat, lng, category)
        except:
            record = (latitude, longitude, number_of_venues, i, '', '', '', '', '')
        
        venue_list.append(record)
        
        
    return( venue_list )

# %% [markdown]
# # Reykjavik

# %%
# Coordinates of Reykjavik
latitude = 64.1466
longitude = -21.9426

# Box boundaries
y_max = latitude + 0.02
y_min = latitude - 0.06
x_max = longitude + 0.18
x_min = longitude - 0.06


lat_centre = (y_max+y_min)/2.0

y_step = 1.0/(110.574)
x_step = 1.0/(111.32*np.cos(2.0*np.pi*lat_centre/360.0))

num_x_points = int((x_max-x_min)/x_step)
num_y_points = int((y_max-y_min)/y_step)

lats = np.linspace(x_min,x_max,num_x_points)
longs = np.linspace(y_min,y_max,num_y_points)

' Create matrix of coordinate values '
coord_list = []
for x in longs:
    for y in lats:
        
        coord_list.append( (x,y) )

print("Number of points = {}".format(len(coord_list)))
# Out:
# Number of points = 88

# %%
# Coordinates of Reykjavik
latitude = 64.1466
longitude = -21.9426

# create map of Toronto using latitude and longitude values
map_reykjavik = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for coord in coord_list:
    lat = coord[0]
    lng = coord[1]
    label = '{} {}'.format(lat,lng)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=1,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_reykjavik)  
    
map_reykjavik
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Retrieve data from Foursquare

# %%
record_list = []

for coord in coord_list:
    
    lat = coord[0]
    lng = coord[1]
    
    venue_details = getVenues(lat, lng)
    
    record_list.extend(venue_details)
    
    print("lat = {} long = {} Number of Venues = {}".format(lat,lng,len(venue_details)))

    
col_names = ['lat_centre','long_centre','num_venues','venue_iter','venue_id','venue_name','lat_venue','long_venue','category']
df_venues = pd.DataFrame.from_records(record_list,columns=col_names)  

df_venues.to_csv('reykjavik_20201212_2345.csv',encoding='utf-8')
# Out:
# lat = 64.0866 long = -22.0026 Number of Venues = 0
# lat = 64.0866 long = -21.9786 Number of Venues = 0
# lat = 64.0866 long = -21.9546 Number of Venues = 0
# lat = 64.0866 long = -21.9306 Number of Venues = 0
# lat = 64.0866 long = -21.9066 Number of Venues = 0
# lat = 64.0866 long = -21.8826 Number of Venues = 0
# lat = 64.0866 long = -21.8586 Number of Venues = 0
# lat = 64.0866 long = -21.8346 Number of Venues = 1
# lat = 64.0866 long = -21.8106 Number of Venues = 0
# lat = 64.0866 long = -21.7866 Number of Venues = 0
# lat = 64.0866 long = -21.7626 Number of Venues = 0
# lat = 64.0980285714 long = -22.0026 Number of Venues = 0
# lat = 64.0980285714 long = -21.9786 Number of Venues = 0
# lat = 64.0980285714 long = -21.9546 Number of Venues = 0
# lat = 64.0980285714 long = -21.9306 Number of Venues = 0
# lat = 64.0980285714 long = -21.9066 Number of Venues = 0
# lat = 64.0980285714 long = -21.8826 Number of Venues = 6
# lat = 64.0980285714 long = -21.8586 Number of Venues = 0
# lat = 64.0980285714 long = -21.8346 Number of Venues = 0
# lat = 64.0980285714 long = -21.8106 Number of Venues = 0
# lat = 64.0980285714 long = -21.7866 Number of Venues = 0
# lat = 64.0980285714 long = -21.7626 Number of Venues = 0
# lat = 64.1094571429 long = -22.0026 Number of Venues = 0
# lat = 64.1094571429 long = -21.9786 Number of Venues = 0
# lat = 64.1094571429 long = -21.9546 Number of Venues = 0
# lat = 64.1094571429 long = -21.9306 Number of Venues = 0
# lat = 64.1094571429 long = -21.9066 Number of Venues = 4
# lat = 64.1094571429 long = -21.8826 Number of Venues = 2
# lat = 64.1094571429 long = -21.8586 Number of Venues = 2
# lat = 64.1094571429 long = -21.8346 Number of Venues = 1
# lat = 64.1094571429 long = -21.8106 Number of Venues = 4
# lat = 64.1094571429 long = -21.7866 Number of Venues = 1
# lat = 64.1094571429 long = -21.7626 Number of Venues = 0
# lat = 64.1208857143 long = -22.0026 Number of Venues = 0
# lat = 64.1208857143 long = -21.9786 Number of Venues = 0
# lat = 64.1208857143 long = -21.9546 Number of Venues = 0
# lat = 64.1208857143 long = -21.9306 Number of Venues = 1
# lat = 64.1208857143 long = -21.9066 Number of Venues = 0
# lat = 64.1208857143 long = -21.8826 Number of Venues = 0
# lat = 64.1208857143 long = -21.8586 Number of Venues = 0
# lat = 64.1208857143 long = -21.8346 Number of Venues = 2
# lat = 64.1208857143 long = -21.8106 Number of Venues = 1
# lat = 64.1208857143 long = -21.7866 Number of Venues = 1
# lat = 64.1208857143 long = -21.7626 Number of Venues = 0
# lat = 64.1323142857 long = -22.0026 Number of Venues = 0
# lat = 64.1323142857 long = -21.9786 Number of Venues = 0
# lat = 64.1323142857 long = -21.9546 Number of Venues = 1
# lat = 64.1323142857 long = -21.9306 Number of Venues = 1
# lat = 64.1323142857 long = -21.9066 Number of Venues = 1
# lat = 64.1323142857 long = -21.8826 Number of Venues = 9
# lat = 64.1323142857 long = -21.8586 Number of Venues = 4
# lat = 64.1323142857 long = -21.8346 Number of Venues = 0
# lat = 64.1323142857 long = -21.8106 Number of Venues = 1
# lat = 64.1323142857 long = -21.7866 Number of Venues = 0
# lat = 64.1323142857 long = -21.7626 Number of Venues = 0
# lat = 64.1437428571 long = -22.0026 Number of Venues = 0
# lat = 64.1437428571 long = -21.9786 Number of Venues = 1
# lat = 64.1437428571 long = -21.9546 Number of Venues = 3
# lat = 64.1437428571 long = -21.9306 Number of Venues = 50
# lat = 64.1437428571 long = -21.9066 Number of Venues = 23
# lat = 64.1437428571 long = -21.8826 Number of Venues = 5
# lat = 64.1437428571 long = -21.8586 Number of Venues = 0
# lat = 64.1437428571 long = -21.8346 Number of Venues = 0
# lat = 64.1437428571 long = -21.8106 Number of Venues = 0
# lat = 64.1437428571 long = -21.7866 Number of Venues = 2
# lat = 64.1437428571 long = -21.7626 Number of Venues = 0
# lat = 64.1551714286 long = -22.0026 Number of Venues = 0
# lat = 64.1551714286 long = -21.9786 Number of Venues = 0
# lat = 64.1551714286 long = -21.9546 Number of Venues = 7
# lat = 64.1551714286 long = -21.9306 Number of Venues = 1
# lat = 64.1551714286 long = -21.9066 Number of Venues = 0
# lat = 64.1551714286 long = -21.8826 Number of Venues = 0
# lat = 64.1551714286 long = -21.8586 Number of Venues = 0
# lat = 64.1551714286 long = -21.8346 Number of Venues = 0
# lat = 64.1551714286 long = -21.8106 Number of Venues = 0
# lat = 64.1551714286 long = -21.7866 Number of Venues = 0
# lat = 64.1551714286 long = -21.7626 Number of Venues = 0
# lat = 64.1666 long = -22.0026 Number of Venues = 0
# lat = 64.1666 long = -21.9786 Number of Venues = 0
# lat = 64.1666 long = -21.9546 Number of Venues = 0
# lat = 64.1666 long = -21.9306 Number of Venues = 0
# lat = 64.1666 long = -21.9066 Number of Venues = 0
# lat = 64.1666 long = -21.8826 Number of Venues = 0
# lat = 64.1666 long = -21.8586 Number of Venues = 0
# lat = 64.1666 long = -21.8346 Number of Venues = 0
# lat = 64.1666 long = -21.8106 Number of Venues = 0
# lat = 64.1666 long = -21.7866 Number of Venues = 0
# lat = 64.1666 long = -21.7626 Number of Venues = 0

# %%
print("Limit breached in {} sites".format(sum(df_venues['num_venues']==50)/50))
np.unique(df_venues[df_venues['num_venues']==50][['lat_centre','long_centre']], axis=0)
# Out:
# Limit breached in 1 sites
# array([[ 64.14374286, -21.9306    ]])

# %% [markdown]
# ## Calculate new site locations at breached points

# %%
zoom_coord_list = np.unique(df_venues[df_venues['num_venues']==50][['lat_centre','long_centre']], axis=0).tolist()

# %%
coord_list = []

for coord in zoom_coord_list:
    
    x = coord[1]
    y = coord[0]
    
    y_step = 1.0/(110.574)
    x_step = 1.0/(111.32*np.cos(2.0*np.pi*y/360.0))

    xleft = x - (x_step/4.0)
    xright = x + (x_step/4.0)
    ytop = y + (y_step/4.0)
    ybottom = y - (y_step/4.0)
    
    coord_list.append( (y,x) )
    coord_list.append( (ytop,xleft) )
    coord_list.append( (ybottom,xleft) )
    coord_list.append( (ytop,xright) )
    coord_list.append( (ybottom,xright) )

# %%
# Coordinates of Reykjavik
latitude = 64.1466
longitude = -21.9426

# create map of Toronto using latitude and longitude values
map_reykjavik = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for coord in coord_list:
    lat = coord[0]
    lng = coord[1]
    label = '{} {}'.format(lat,lng)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=1,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_reykjavik)  
    
map_reykjavik
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Retrieve info from Foursquare

# %%
record_list = []

for coord in coord_list:
    
    lat = coord[0]
    lng = coord[1]
    
    venue_details = getVenues(lat, lng, RADIUS=250)
    
    record_list.extend(venue_details)
    
    print("lat = {} long = {} Number of Venues = {}".format(lat,lng,len(venue_details)))

    
col_names = ['lat_centre','long_centre','num_venues','venue_iter','venue_id','venue_name','lat_venue','long_venue','category']
df_venues = pd.DataFrame.from_records(record_list,columns=col_names)  

df_venues.to_csv('reykjavik_20201210_2350.csv',encoding='utf-8')
# Out:
# lat = 64.1437428571 long = -21.9306 Number of Venues = 13
# lat = 64.1460037865 long = -21.9357495099 Number of Venues = 39
# lat = 64.1414819278 long = -21.9357495099 Number of Venues = 2
# lat = 64.1460037865 long = -21.9254504901 Number of Venues = 20
# lat = 64.1414819278 long = -21.9254504901 Number of Venues = 2

# %%
print("Limit breached in {} sites".format(sum(df_venues['num_venues']==50)/50))
# Out:
# Limit breached in 0 sites

# %% [markdown]
# ## Combine all files into single file

# %%
import os
files = os.listdir('.')

file_pattern = 'reykjavik_'

venue_files = []

' Obtain all files holding venue info '
for filename in files:
    if file_pattern in filename:
        venue_files.append(filename)

' Read in files into dataframe '
df_venues = pd.DataFrame()
for filename in venue_files:
    df = pd.read_csv(filename,encoding='utf-8')
    print( "File: {} Records: {}".format(filename,len(df)) )
    df_venues = df_venues.append(df, ignore_index = True)
# Out:
# File: reykjavik_20201212_2345.csv Records: 135
# File: reykjavik_20201210_2350.csv Records: 76

# %% [markdown]
# ## Remove duplicate entries and clean up data

# %%
df_venues.sort_values("venue_id", inplace = True)
df_venues.drop_duplicates(subset ="venue_id", keep = False, inplace = True)
df_venues.to_csv('reykjavik_all.csv',encoding='utf-8')

# %%
' Keep only venues with "Restaurant" in their category title '
df_venues['restaurant'] = df_venues['category'].apply(lambda x: True if 'Restaurant' in x else False)
df_venues = df_venues[df_venues['restaurant'] == True]
df_venues.drop('restaurant', axis=1, inplace=True)
df_venues.to_csv('reykjavik_restaurants.csv',encoding='utf-8')

# %%
from folium.plugins import FastMarkerCluster

# Coordinates of Reykjavik
latitude = 64.1466
longitude = -21.9426

# create map of Zurich using latitude and longitude values
map_reykjavik = folium.Map(location=[latitude, longitude], zoom_start=10)

FastMarkerCluster(data=list(zip(df_venues['lat_venue'],df_venues['long_venue']))).add_to(map_reykjavik)

folium.LayerControl().add_to(map_reykjavik);

map_reykjavik
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
