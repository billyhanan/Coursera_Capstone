# %% [markdown]
# # Capstone Project: Data Collection
#
# 29/11/2020
#
# We collect restaurant data via the Foursquare API.

# %%
import pandas as pd
import numpy as np
import requests 
import json # library to handle JSON files
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
#!pip install folium
import folium # map rendering library

# %%
# Coordinates of Athens
latitude = 37.9838
longitude = 23.7275

# create map of Toronto using latitude and longitude values
map_athens = folium.Map(location=[latitude, longitude], zoom_start=11)

map_athens
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# @hidden_cell
CLIENT_ID = '34CRGBIL11CRLO5BNFSRKHWNRQT1GWTB4QKGYG5GLQYM3JKQ' # your Foursquare ID
CLIENT_SECRET = 'HRPY3HMJC1FSPYTC2VRVUANCY1JY20NBRA5400RQYOEOFCNB' # your Foursquare Secret
#VERSION = '20180605' # Foursquare API version
VERSION = '20201123' # Foursquare API version
RADIUS=500
LIMIT = 50 # A default Foursquare API limit value

# %%
# List of categories
afghan = '503288ae91d4c4b30a586d67'
african = '4bf58dd8d48988d1c8941735'
american = '4bf58dd8d48988d14e941735'
asian = '4bf58dd8d48988d142941735'
australian = '4bf58dd8d48988d169941735'
austrian = '52e81612bcbc57f1066b7a01'
bangladesh = '5e179ee74ae8e90006e9a746'
belgium = '52e81612bcbc57f1066b7a02'
cajun = '4bf58dd8d48988d17a941735'
caribbean = '4bf58dd8d48988d144941735'
caucasian = '5293a7d53cf9994f4e043a45'
czech = '52f2ae52bcbc57f1066b8b81'
dutch = '5744ccdfe4b0c0459246b4d0'
eastEurope = '4bf58dd8d48988d109941735'
english = '52e81612bcbc57f1066b7a05'
french = '4bf58dd8d48988d10c941735'
german = '4bf58dd8d48988d10d941735'
greek = '4bf58dd8d48988d10e941735'
hungary = '52e81612bcbc57f1066b79fa'
indian = '4bf58dd8d48988d10f941735'
italian = '4bf58dd8d48988d110941735'
jewish = '52e81612bcbc57f1066b79fd'
latin = '4bf58dd8d48988d1be941735'
meditarranean = '4bf58dd8d48988d1c0941735'
mexican = '4bf58dd8d48988d1c1941735'
middleEast = '4bf58dd8d48988d115941735'
modernEuropean = '52e81612bcbc57f1066b79f9'
pakistan = '52e81612bcbc57f1066b79f8'
polish = '52e81612bcbc57f1066b7a04'
portugal = '4def73e84765ae376e57713a'
russia = '5293a7563cf9994f4e043a44'
scandinavia = '4bf58dd8d48988d1c6941735'
scotland = '5744ccdde4b0c0459246b4a3'
slovak = '56aa371be4b08b9a8d57355a'
spain = '4bf58dd8d48988d150941735'
srilanka = '5413605de4b0ae91d18581a9'
swiss = '4bf58dd8d48988d158941735'
turkey = '4f04af1f2fb6e1c99f3db0bb'
ukraine = '52e928d0bcbc57f1066b7e96'

category_list = [afghan,african,american,asian,australian,austrian,bangladesh,belgium,cajun,caribbean,caucasian,czech,dutch,eastEurope,english,
                 french,german,greek,hungary,indian,italian,jewish,latin,meditarranean,mexican,middleEast,modernEuropean,pakistan,polish,
                 portugal,russia,scandinavia,scotland,slovak,spain,srilanka,swiss,turkey,ukraine] 

CATEGORIES = ','.join(category_list)

# %%
def getVenues(latitude, longitude, RADIUS=500):
    
    url = 'https://api.foursquare.com/v2/venues/search?&categoryId={}&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&intent=browse'.format(
            CATEGORIES,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            latitude, 
            longitude, 
            RADIUS,
            LIMIT)
    
    results = requests.get(url).json()
    
    venues = results['response']['venues']
        
    venue_list = []
    
    number_of_venues = len(venues)
    
    for i in range(number_of_venues):
        
        try:
            venue_id = venues[i]['id']
            venue_name = venues[i]['name']
            lat = venues[i]['location']['lat']
            lng = venues[i]['location']['lng']
            category = venues[i]['categories'][0]['name']
            
            record = (latitude, longitude, number_of_venues, i, venue_id, venue_name, lat, lng, category)
        except:
            record = (latitude, longitude, number_of_venues, i, '', '', '', '', '')
        
        venue_list.append(record)
        
        
    return( venue_list )

# %% [markdown]
# # Athens

# %%
# Coordinates of Athens
latitude = 37.9838
longitude = 23.7275

# Box boundaries
y_max = latitude + 0.06
y_min = latitude - 0.04
x_max = longitude + 0.06
x_min = longitude - 0.06

lat_centre = (y_max+y_min)/2.0

y_step = 1.0/(110.574)
x_step = 1.0/(111.32*np.cos(2.0*np.pi*lat_centre/360.0))

num_x_points = int((x_max-x_min)/x_step)
num_y_points = int((y_max-y_min)/y_step)

lats = np.linspace(x_min,x_max,num_x_points)
longs = np.linspace(y_min,y_max,num_y_points)

' Create matrix of coordinate values '
coord_list = []
for x in longs:
    for y in lats:
        
        coord_list.append( (x,y) )

print("Number of points = {}".format(len(coord_list)))
# Out:
# Number of points = 110

# %%
# Coordinates of Athens
latitude = 37.9838
longitude = 23.7275

# create map of Toronto using latitude and longitude values
map_athens = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for coord in coord_list:
    lat = coord[0]
    lng = coord[1]
    label = '{} {}'.format(lat,lng)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_athens)  
    
map_athens
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Retrieve data from Foursquare

# %%
record_list = []

for coord in coord_list:
    
    lat = coord[0]
    lng = coord[1]
    
    venue_details = getVenues(lat, lng)
    
    record_list.extend(venue_details)
    
    print("lat = {} long = {} Number of Venues = {}".format(lat,lng,len(venue_details)))

    
col_names = ['lat_centre','long_centre','num_venues','venue_iter','venue_id','venue_name','lat_venue','long_venue','category']
df_venues = pd.DataFrame.from_records(record_list,columns=col_names)  

df_venues.to_csv('athens_20201208_2320.csv',encoding='utf-8')
# Out:
# lat = 37.9438 long = 23.6675 Number of Venues = 13
# lat = 37.9438 long = 23.6808333333 Number of Venues = 16
# lat = 37.9438 long = 23.6941666667 Number of Venues = 30
# lat = 37.9438 long = 23.7075 Number of Venues = 18
# lat = 37.9438 long = 23.7208333333 Number of Venues = 14
# lat = 37.9438 long = 23.7341666667 Number of Venues = 26
# lat = 37.9438 long = 23.7475 Number of Venues = 13
# lat = 37.9438 long = 23.7608333333 Number of Venues = 13
# lat = 37.9438 long = 23.7741666667 Number of Venues = 12
# lat = 37.9438 long = 23.7875 Number of Venues = 0
# lat = 37.9538 long = 23.6675 Number of Venues = 8
# lat = 37.9538 long = 23.6808333333 Number of Venues = 30
# lat = 37.9538 long = 23.6941666667 Number of Venues = 22
# lat = 37.9538 long = 23.7075 Number of Venues = 30
# lat = 37.9538 long = 23.7208333333 Number of Venues = 33
# lat = 37.9538 long = 23.7341666667 Number of Venues = 27
# lat = 37.9538 long = 23.7475 Number of Venues = 22
.unique(df_venues[df_venues['num_venues']==50][['lat_centre','long_centre']], axis=0).tolist()

# %%
coord_list = []

for coord in zoom_coord_list:
    
    x = coord[1]
    y = coord[0]
    
    y_step = 1.0/(110.574)
    x_step = 1.0/(111.32*np.cos(2.0*np.pi*y/360.0))

    xleft = x - (x_step/4.0)
    xright = x + (x_step/4.0)
    ytop = y + (y_step/4.0)
    ybottom = y - (y_step/4.0)
    
    coord_list.append( (y,x) )
    coord_list.append( (ytop,xleft) )
    coord_list.append( (ybottom,xleft) )
    coord_list.append( (ytop,xright) )
    coord_list.append( (ybottom,xright) )

# %%
# Coordinates of Athens
latitude = 37.9838
longitude = 23.7275

# create map of Toronto using latitude and longitude values
map_athens = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for coord in coord_list:
    lat = coord[0]
    lng = coord[1]
    label = '{} {}'.format(lat,lng)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_athens)  
    
map_athens
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Retrieve info from Foursquare

# %%
record_list = []

for coord in coord_list:
    
    lat = coord[0]
    lng = coord[1]
    
    venue_details = getVenues(lat, lng, RADIUS=250)
    
    record_list.extend(venue_details)
    
    print("lat = {} long = {} Number of Venues = {}".format(lat,lng,len(venue_details)))

    
col_names = ['lat_centre','long_centre','num_venues','venue_iter','venue_id','venue_name','lat_venue','long_venue','category']
df_venues = pd.DataFrame.from_records(record_list,columns=col_names)  

df_venues.to_csv('athens_20201208_2330.csv',encoding='utf-8')
# Out:
# lat = 37.9638 long = 23.7075 Number of Venues = 7
# lat = 37.9660609293 long = 23.7046514724 Number of Venues = 12
# lat = 37.9615390707 long = 23.7046514724 Number of Venues = 5
# lat = 37.9660609293 long = 23.7103485276 Number of Venues = 16
# lat = 37.9615390707 long = 23.7103485276 Number of Venues = 8
# lat = 37.9738 long = 23.7208333333 Number of Venues = 17
# lat = 37.9760609293 long = 23.7179844177 Number of Venues = 24
# lat = 37.9715390707 long = 23.7179844177 Number of Venues = 0
# lat = 37.9760609293 long = 23.7236822489 Number of Venues = 50
# lat = 37.9715390707 long = 23.7236822489 Number of Venues = 3
# lat = 37.9738 long = 23.7341666667 Number of Venues = 50
# lat = 37.9760609293 long = 23.7313177511 Number of Venues = 50
# lat = 37.9715390707 long = 23.7313177511 Number of Venues = 39
# lat = 37.9760609293 long = 23.7370155823 Number of Venues = 21
# lat = 37.9715390707 long = 23.7370155823 Number of Venues = 4
# lat = 37.9738 long = 23.7475 Number of Venues = 7
# lat = 37.9760609293 long = 23.7446510844 Number of Venues = 16
# lat = 37.9715390707 long = 23.7446510844 Number of Venues = 31
# lat = 37.9760609293 long = 23.7503489156 Number of Venues = 18
# lat = 37.9715390707 long = 23.7503489156 Number of Venues = 14
# lat = 37.9838 long = 23.7208333333 Number of Venues = 24
# lat = 37.9860609293 long = 23.7179840295 Number of Venues = 5
# lat = 37.9815390707 long = 23.7179840295 Number of Venues = 27
# lat = 37.9860609293 long = 23.7236826371 Number of Venues = 26
# lat = 37.9815390707 long = 23.7236826371 Number of Venues = 34
# lat = 37.9838 long = 23.7341666667 Number of Venues = 50
# lat = 37.9860609293 long = 23.7313173629 Number of Venues = 50
# lat = 37.9815390707 long = 23.7313173629 Number of Venues = 14
# lat = 37.9860609293 long = 23.7370159705 Number of Venues = 43
# lat = 37.9815390707 long = 23.7370159705 Number of Venues = 26
# lat = 37.9838 long = 23.7608333333 Number of Venues = 17
# lat = 37.9860609293 long = 23.7579840295 Number of Venues = 9
# lat = 37.9815390707 long = 23.7579840295 Number of Venues = 13
# lat = 37.9860609293 long = 23.7636826371 Number of Venues = 14
# lat = 37.9815390707 long = 23.7636826371 Number of Venues = 29
# lat = 37.9938 long = 23.6808333333 Number of Venues = 28
# lat = 37.9960609293 long = 23.6779836411 Number of Venues = 0
# lat = 37.9915390707 long = 23.6779836411 Number of Venues = 41
# lat = 37.9960609293 long = 23.6836830255 Number of Venues = 4
# lat = 37.9915390707 long = 23.6836830255 Number of Venues = 8
# lat = 37.9938 long = 23.7608333333 Number of Venues = 12
# lat = 37.9960609293 long = 23.7579836411 Number of Venues = 4
# lat = 37.9915390707 long = 23.7579836411 Number of Venues = 7
# lat = 37.9960609293 long = 23.7636830255 Number of Venues = 17
# lat = 37.9915390707 long = 23.7636830255 Number of Venues = 31
# lat = 38.0138 long = 23.6941666667 Number of Venues = 20
# lat = 38.0160609293 long = 23.6913161971 Number of Venues = 8
# lat = 38.0115390707 long = 23.6913161971 Number of Venues = 25
# lat = 38.0160609293 long = 23.6970171363 Number of Venues = 7
# lat = 38.0115390707 long = 23.6970171363 Number of Venues = 20

# %%
print("Limit breached in {} sites".format(sum(df_venues['num_venues']==50)/50))
np.unique(df_venues[df_venues['num_venues']==50][['lat_centre','long_centre']], axis=0)
# Out:
# Limit breached in 5 sites
# array([[37.9738    , 23.73416667],
#        [37.97606093, 23.72368225],
#        [37.97606093, 23.73131775],
#        [37.9838    , 23.73416667],
#        [37.98606093, 23.73131736]])

# %% [markdown]
# ## Calculate new site locations at breached points

# %%
zoom_coord_list = np.unique(df_venues[df_venues['num_venues']==50][['lat_centre','long_centre']], axis=0).tolist()

# %%
coord_list = []

for coord in zoom_coord_list:
    
    x = coord[1]
    y = coord[0]
    
    y_step = 1.0/(110.574)
    x_step = 1.0/(111.32*np.cos(2.0*np.pi*y/360.0))

    xleft = x - (x_step/8.0)
    xright = x + (x_step/8.0)
    ytop = y + (y_step/8.0)
    ybottom = y - (y_step/8.0)
    
    coord_list.append( (y,x) )
    coord_list.append( (ytop,xleft) )
    coord_list.append( (ybottom,xleft) )
    coord_list.append( (ytop,xright) )
    coord_list.append( (ybottom,xright) )

# %%
# Coordinates of Athens
latitude = 37.9838
longitude = 23.7275

# create map of Toronto using latitude and longitude values
map_athens = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for coord in coord_list:
    lat = coord[0]
    lng = coord[1]
    label = '{} {}'.format(lat,lng)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_athens)  
    
map_athens
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Retrieve info from Foursquare

# %%
record_list = []

for coord in coord_list:
    
    lat = coord[0]
    lng = coord[1]
    
    venue_details = getVenues(lat, lng, RADIUS=100)
    
    record_list.extend(venue_details)
    
    print("lat = {} long = {} Number of Venues = {}".format(lat,lng,len(venue_details)))

    
col_names = ['lat_centre','long_centre','num_venues','venue_iter','venue_id','venue_name','lat_venue','long_venue','category']
df_venues = pd.DataFrame.from_records(record_list,columns=col_names)  

df_venues.to_csv('athens_20201208_2335.csv',encoding='utf-8')
# Out:
# lat = 37.9738 long = 23.7341666667 Number of Venues = 11
# lat = 37.9749304647 long = 23.7327422089 Number of Venues = 38
# lat = 37.9726695353 long = 23.7327422089 Number of Venues = 10
# lat = 37.9749304647 long = 23.7355911245 Number of Venues = 5
# lat = 37.9726695353 long = 23.7355911245 Number of Venues = 1
# lat = 37.9760609293 long = 23.7236822489 Number of Venues = 29
# lat = 37.977191394 long = 23.7222577473 Number of Venues = 28
# lat = 37.9749304647 long = 23.7222577473 Number of Venues = 0
# lat = 37.977191394 long = 23.7251067506 Number of Venues = 17
# lat = 37.9749304647 long = 23.7251067506 Number of Venues = 5
# lat = 37.9760609293 long = 23.7313177511 Number of Venues = 20
# lat = 37.977191394 long = 23.7298932494 Number of Venues = 18
# lat = 37.9749304647 long = 23.7298932494 Number of Venues = 9
# lat = 37.977191394 long = 23.7327422527 Number of Venues = 11
# lat = 37.9749304647 long = 23.7327422527 Number of Venues = 38
# lat = 37.9838 long = 23.7341666667 Number of Venues = 11
# lat = 37.9849304647 long = 23.7327420148 Number of Venues = 15
# lat = 37.9826695353 long = 23.7327420148 Number of Venues = 6
# lat = 37.9849304647 long = 23.7355913186 Number of Venues = 11
# lat = 37.9826695353 long = 23.7355913186 Number of Venues = 4
# lat = 37.9860609293 long = 23.7313173629 Number of Venues = 9
# lat = 37.987191394 long = 23.7298926671 Number of Venues = 2
# lat = 37.9849304647 long = 23.7298926671 Number of Venues = 6
# lat = 37.987191394 long = 23.7327420587 Number of Venues = 2
# lat = 37.9849304647 long = 23.7327420587 Number of Venues = 15

# %% [markdown]
# ## Combine all files into single file

# %%
import os
files = os.listdir('.')

file_pattern = 'athens_'

venue_files = []

' Obtain all files holding venue info '
for filename in files:
    if file_pattern in filename:
        venue_files.append(filename)

' Read in files into dataframe '
df_venues = pd.DataFrame()
for filename in venue_files:
    df = pd.read_csv(filename,encoding='utf-8')
    print( "File: {} Records: {}".format(filename,len(df)) )
    df_venues = df_venues.append(df, ignore_index = True)
# Out:
# File: athens_20201208_2335.csv Records: 321
# File: athens_20201208_2320.csv Records: 1975
# File: athens_20201208_2330.csv Records: 1005

# %% [markdown]
# ## Remove duplicate entries and clean up data

# %%
df_venues.sort_values("venue_id", inplace = True)
df_venues.drop_duplicates(subset ="venue_id", keep = False, inplace = True)
df_venues.to_csv('athens_all.csv',encoding='utf-8')

# %%
' Keep only venues with "Restaurant" in their category title '
df_venues['restaurant'] = df_venues['category'].apply(lambda x: True if 'Restaurant' in x else False)
df_venues = df_venues[df_venues['restaurant'] == True]
df_venues.drop('restaurant', axis=1, inplace=True)
df_venues.to_csv('athens_restaurants.csv',encoding='utf-8')

# %%
# Coordinates of Athens
latitude = 37.9838
longitude = 23.7275

from folium.plugins import FastMarkerCluster

# create map of Zurich using latitude and longitude values
map_athens = folium.Map(location=[latitude, longitude], zoom_start=11)

FastMarkerCluster(data=list(zip(df_venues['lat_venue'],df_venues['long_venue']))).add_to(map_athens)

folium.LayerControl().add_to(map_athens);

map_athens
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
